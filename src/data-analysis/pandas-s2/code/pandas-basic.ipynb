# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s = pd.Series([1, 2, 3, 4], index = ['a', 'b', 'c', 'd'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data = [[1, 444, 'abc'],
        [2, 555, 'def'],
        [3, 666, 'ghi'],
        [4, 444, 'xyz']]

df = pd.DataFrame(data, columns=['idx', 'std_id', 'depar'])
df
# Out:
#    idx  std_id depar
# 0    1     444   abc
# 1    2     555   def
# 2    3     666   ghi
# 3    4     444   xyz

# %%
data = {'idx' : [1, 2, 3, 4],
        'std_id' : [444, 555, 666, 444],
        'depart' : ['abc', 'def', 'ghi', 'xyz']
        }
df = pd.DataFrame(data)
df
# Out:
#    idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
colums = ['idx-1', 'std_id1', 'dep']
idx = ['a', 'b', 'c', 'd']
df.index = idx
df.columns = colums
display(df)
# Out:
#    idx-1  std_id1  dep
# a      1      444  abc
# b      2      555  def
# c      3      666  ghi
# d      4      444  xyz

# %%
df
# Out:
#    idx-1  std_id1  dep
# a      1      444  abc
# b      2      555  def
# c      3      666  ghi
# d      4      444  xyz

# %%
# df.dtypes
df['idx-1'].dtype
# Out:
# dtype('int64')

# %%
df['std_id1'] = df['std_id1'].astype('category')
df.dtypes
# Out:
# idx-1         int64
# std_id1    category
# dep             str
# dtype: object

# %%
cols = ['idx-1', 'dep']
df[cols] = df[cols].astype('category')

# %%
df.dtypes
# Out:
# idx-1      category
# std_id1    category
# dep        category
# dtype: object

# %%
data = {'idx' : [1, 2, 3, 4],
        'std_id' : [444, 555, 666, 444],
        'depart' : ['abc', 'def', 'ghi', 'xyz']
        }

df = pd.DataFrame(data)
df
# Out:
#    idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
df.head()
# Out:
#    idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
df.tail(1)
# Out:
#    idx  std_id depart
# 3    4     444    xyz

# %%
df['depart'] = df['depart'].astype('category')
df.dtypes
# Out:
# idx          int64
# std_id       int64
# depart    category
# dtype: object

# %%
df.describe(include='category')
# Out:
#        depart
# count       4
# unique      4
# top       abc
# freq        1

# %%
df.describe()
# Out:
#             idx      std_id
# count  4.000000    4.000000
# mean   2.500000  527.250000
# std    1.290994  106.274409
# min    1.000000  444.000000
# 25%    1.750000  444.000000
# 50%    2.500000  499.500000
# 75%    3.250000  582.750000
# max    4.000000  666.000000

# %%
df.columns
# Out:
# Index(['idx', 'std_id', 'depart'], dtype='str')

# %%
df['std_id'].unique()
df['std_id'].nunique()
# Out:
# 3

# %%
df['std_id'].idxmin()
df['std_id'].idxmax()
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   idx     4 non-null      int64
#  1   std_id  4 non-null      int64
#  2   depart  4 non-null      category
# dtypes: category(1), int64(2)
# memory usage: 404.0 bytes

# %%
d = df['std_id'].value_counts()
d
# Out:
# std_id
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
x = df.values
type(x)
# Out:
# numpy.ndarray

# %%
df1 =df.replace(555, 'fahd', inplace = True)
df1
# Out:
#    idx std_id depart
# 0    1    444    abc
# 1    2   fahd    def
# 2    3    666    ghi
# 3    4    444    xyz

# %%
df
# Out:
#    idx std_id depart
# 0    1    444    abc
# 1    2   fahd    def
# 2    3    666    ghi
# 3    4    444    xyz

# %%
df.std_id = df.std_id.map({444:6564, 555:65488})

# %%
df
# Out:
#    idx  std_id  depart
# 0    1  6564.0     NaN
# 1    2     NaN     NaN
# 2    3     NaN     NaN
# 3    4  6564.0     NaN

# %%
data = {'idx' : [1, 2, 3, 4],
        'std_id' : [444, 555, 666, 444],
        'depart' : ['abc', 'def', 'ghi', 'xyz']
        }

df = pd.DataFrame(data)
df
# Out:
#    idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
df.iloc[2,1]
# Out:
# np.int64(666)

# %%
df.iloc[:]
# Out:
#    idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
x = df.iloc[: , : 2]
y = df.iloc[ : , -1]
x
# Out:
#    idx  std_id
# 0    1     444
# 1    2     555
# 2    3     666
# 3    4     444
