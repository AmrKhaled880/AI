# %%
List_one = [1, 2, 3, 4, "Depi", "Machine Learinig", True, [1, 2, 3, 'True', ['ml', 'dl', 'llm']]]

List_one[7][4][1] = "DS"

# %%
print(List_one)
# Out:
# [1, 2, 3, 4, 'Depi', 'Machine Learinig', True, [1, 2, 3, 'True', ['ml', 'DS', 'llm']]]

# %%
list_1 = ["Depi", "ml", "genai"]
list_1.append("Deep Learning")
print(list_1)
# Out:
# ['Depi', 'ml', 'genai', 'Deep Learning']

# %%
list_1.insert(0,"NLP")
print(list_1)
# Out:
# ['NLP', 'Depi', 'ml', 'genai', 'Deep Learning']

# %%
new_list = [1, 2, 3, 4, 'Depi', 'Machine Learinig', 'Depi', True, [1, 2, 3, 'True', ['ml', 'DS', 'llm']]]

# %%
new_list.remove('Depi')
print(new_list)
# Out:
# [1, 2, 3, 4, 'Machine Learinig', 'Depi', True, [1, 2, 3, 'True', ['ml', 'DS', 'llm']]]

# %%
list_1.extend("Amr")
print(list_1)
# Out:
# ['NLP', 'Depi', 'ml', 'genai', 'Deep Learning', 'A', 'm', 'r']

# %%
list_2 = ["depi", "ml", "ai"]
x = list_2.pop()

# %%
new_list.append(x)
print(new_list)
# Out:
# [1, 2, 3, 4, 'Machine Learinig', 'Depi', True, [1, 2, 3, 'True', ['ml', 'DS', 'llm']], 'ai']

# %%
del list_2[0]
print(list_2)
# Out:
# ['ml']

# %%
del list_2 
print(list_2)   # Its already deleated
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 del list_2
# ----> 2 print(list_2)   # Its already deleated
#
# NameError: name 'list_2' is not defined

# %%
name = input("Enter Your name")
new_name = list(name)
age = int(input("Enter Your age"))
print(f"My name is {name} ,And My age is {age}")
# Out:
# My name is Amr ,And My age is 21

# %%
input_list = ['Amit', 'Learning', 'python', 'machine learning', 'deep learning', 'data science']
word_remove = input("Enter Your word to reomved from input_list")
word_removed = list(word_remove)
input_list.remove(word_remove)
print(input_list)
# Out:
# ['Amit', 'Learning', 'machine learning', 'deep learning', 'data science']

# %%
list_5 = [4, 7, 8, 9, 1]
list_5.sort()                 #Ascending
list_5
# Out:
# [1, 4, 7, 8, 9]

# %%
list_5.reverse()
print(list_5)          #Descening
# Out:
# [9, 8, 7, 4, 1]

# %%
list_5.clear()      # == del list_5[:]
print(list_5)
# Out:
# []

# %%
tuple_1 = (1, 2, 3, 10)
print(type(tuple_1))
# Out:
# <class 'tuple'>

# %%
tuple_1[1] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 tuple_1[1] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_list = []
my_list = list(tuple_1)

# %%
print(my_list)
# Out:
# [1, 2, 3, 10]

# %%
set1 = {1, 2, 3}
print(type(set1))
# Out:
# <class 'set'>

# %%
set1[0] = 5           #Set Unchangeable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 set1[0] = 5
#
# TypeError: 'set' object does not support item assignment

# %%
a = {1, 2, 3}
b = {3, 4, 5}
print(a | b)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(a.union(b))
print(a.intersection(b))
# Out:
# {1, 2, 3, 4, 5}
# {3}

# %%
dict_1 = {"Key1" : 13.4, "Key2" : 6}
print(dict_1)
print(dict())
# Out:
# {'Key1': 13.4, 'Key2': 6}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 dict_1 = {"Key1" : 13.4, "Key2" : 6}
#       2 print(dict_1)
# ----> 3 print(dict.sorted())
#
# AttributeError: type object 'dict' has no attribute 'sorted'

# %%
dict_1['Key1'] = "DEPI"
dict_1
# Out:
# {'Key1': 'DEPI', 'Key2': 6}

# %%
value_1 = [("a",1),("b",2)]
dict_2 = dict(value_1)
print(type(dict_2))
# Out:
# <class 'dict'>

# %%
a = 10
b = 20 
a is b
# Out:
# False

# %%
x = float(input("Enter first number"))
y = float(input("Enter second number"))
print(f"Addition numbs is {x + y}")
print(f"sub numbs is {x - y}")
print(f"multiplication numbs is {x * y}")
print(f"divided numbs is {x / y}")
# Out:
# Addition numbs is 35.0
# sub numbs is -5.0
# multiplication numbs is 300.0
# divided numbs is 0.75
